# %%
import matplotlib.pyplot as plt
import seaborn as sns

class DataPlotter:
    def __init__(self):
        # Set the style and custom palette
        sns.set(style="whitegrid")
        #plt.style.use('seaborn-dark-palette')
        #plt.rcParams['figure.facecolor'] = 'white'
        
        
    def line_graph(self, x_data, y_data, x_label = '', y_label = '', title = '', line_label = 'Line 1'):
        fig, ax = plt.subplots(figsize=(8, 6))
        ax.plot(x_data, y_data, label= line_label, linewidth=4)
        ax.legend(loc="upper right", fontsize=15)
        ax.set_xlabel(x_label, fontsize=15)
        ax.set_ylabel(y_label, fontsize=15)
        ax.set_title(title, fontsize=15)
        fig.canvas.draw()
        plt.tight_layout()
        plt.show()
        

    def scatter(self, x_data, y_data, x_label = '', y_label = '', title = ''):
        plt.figure(figsize=(8, 6))
        plt.scatter(x_data, y_data)
        plt.xlabel(x_label, fontsize=15)
        plt.ylabel(y_label, fontsize=15)
        plt.title(title, fontsize=15)
        plt.tight_layout()
        plt.show()

    def bar_chart(self, x_data, y_data):
        sns.barplot(x=x_data, y=y_data)
        plt.tight_layout()
        plt.show()

    def pie_chart(self, data, labels):
        plt.pie(data, labels=labels, autopct='%1.1f%%')
        plt.axis('equal')
        plt.tight_layout()
        plt.show()

# Example of how to call methods in the DataPlotter class from other parts of the code to get graphs
plotter = DataPlotter()
x_values = [1, 2, 3, 4, 5]
y_values = [10, 20, 15, 25, 30]

# Call the plot_line_graph method
plotter.line_graph(x_values, y_values)

# Call the plot_scatter method
plotter.scatter(x_values, y_values, "X Label", "Y Label", "Scatter Plot Title")

# Call the plot_bar_chart method
plotter.bar_chart(x_values, y_values)

# Call the plot_pie_chart method
plotter.pie_chart([25, 35, 20, 20], ['A', 'B', 'C', 'D'])
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fg = plt.figure(figsize=(8, 6), constrained_layout=True, facecolor = "whitesmoke")
gs = gridspec.GridSpec(ncols=1, nrows=2, figure=fg)

sns.set(style="whitegrid")
fig_ax_1 = fg.add_subplot(gs[0, 0], facecolor = "white")

fig_ax_1.plot(values_x_1, values_y_1, label = '1', linewidth=3, marker = '^', markevery = 5)
fig_ax_1.plot(values_x_2, values_y_2, label = '2', linewidth=3, marker = '.', markevery = 6)
fig_ax_1.plot(values_x_3, values_y_3, label = '3', linewidth=3, marker = 'o', markevery = 7)
fig_ax_1.plot(values_x_4, values_y_4,  label = '4', linewidth=3, marker = '^', markevery = 8)

fig_ax_1.legend(loc="upper right", fontsize=15)
fig_ax_1.semilogy()
fig_ax_1.set_xlabel("xlabel", fontsize=15)
fig_ax_1.set_ylabel("ylabel", fontsize=15)
fig_ax_1.set_title('title, fontsize=15)
fig_ax_1.grid(color='darkred')

fig_ax_2 = fg.add_subplot(gs[0, 1], facecolor = "white")
fig_ax_2.plot(values_x_1, values_y_1], 'teal', label = '1', linewidth=3, marker = '^', markevery = 5)
fig_ax_2.plot(values_x_2, values_y_2, 'coral', label = '2', linewidth=3, marker = '.', markevery = 6)
fig_ax_2.plot(values_x_3, values_y_3, 'royalblue', label = '3', linewidth=3, marker = 'o', markevery = 7)
fig_ax_2.plot(values_x_4, values_y_4, 'darkred', label = '4', linewidth=3, marker = '^', markevery = 8)

fig_ax_2.legend(loc="upper right", fontsize=15)
fig_ax_2.semilogy()
fig_ax_2.set_xlabel("xlabel", fontsize=15)
fig_ax_2.set_ylabel("ylabel", fontsize=15)
fig_ax_2.set_title('title, fontsize=15)
fig_ax_2.grid(color='darkred')
# Out:
#   File "/var/folders/2z/h4ypwr2j2f70t152_xqwp5w40000gn/T/ipykernel_41804/1128090050.py", line 6
#     fig_ax_1.plot(values_x_1, values_y_1], 'teal', label = '1', linewidth=3, marker = '^', markevery = 5)
#                                         ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
